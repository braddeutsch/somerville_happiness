# %% [markdown]
# # Cross tabs
# Assess responses broken down by various demo cuts

# %%
import pandas as pd
import numpy as np

# %%
# load data
data = pd.read_csv('../data/processed/weighted_survey_data.csv')

# %%
data.head()
# Out:
#    year  q01_happy  q02_satisfied_general  q03_satisfied_somerville  \
# 0  2019       10.0                   10.0                      10.0
# 1  2019        7.0                    7.0                       9.0
# 2  2019        9.0                    9.0                       1.0
# 3  2019       10.0                    9.0                       9.0
# 4  2019        8.0                    8.0                       7.0
#
#    q04_satisfied_neighborhood  q06a_city_services  q06b_cost_housing  \
# 0                        10.0                 5.0                4.0
# 1                         8.0                 4.0                2.0
# 2                         1.0                 4.0                1.0
# 3                         8.0                 5.0                5.0
# 4                         7.0                 5.0                3.0
#
#    q06c_quality_schools  q06d_trust_police  q06e_sidewalks  ...  \
# 0                   4.0                5.0             4.0  ...
# ...

# %%
from statsmodels impot

# %%
dummy_cols = ['d01_gender', 'd02_age']

# %%
data['d04_race']
# Out:
# 0               white
# 1               white
# 2               white
# 3               white
# 4               asian
#             ...
# 1491            white
# 1492            white
# 1493            white
# 1494     asian, white
# 1495    euro american
# Name: d04_race, Length: 1496, dtype: object

# %%
data.dtypes
# Out:
# year                            int64
# q01_happy                     float64
# q02_satisfied_general         float64
# q03_satisfied_somerville      float64
# q04_satisfied_neighborhood    float64
# q06a_city_services            float64
# q06b_cost_housing             float64
# q06c_quality_schools          float64
# q06d_trust_police             float64
# q06e_sidewalks                float64
# q06f_events                   float64
# q09_safe_at_night             float64
# q11_beauty                    float64
# q10_parks                     float64
# d01_gender                     object
# d02_age                        object
# d04_race                       object
# d05_num_children              float64
# d06_housing_status             object
# d07_plan_to_move              float64
# d10_how_long_lived_here       float64
# d08_hhi                        object
# d09_is_student                float64
# ward                          float64
# q05_city_direction             object
# ...
