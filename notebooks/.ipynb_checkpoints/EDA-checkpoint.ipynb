# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# load data

data = pd.read_csv('../data/raw/Somerville_Happiness_Survey_Responses.csv')

# %%
# data quality check
print("Total responses: {}".format(len(data)))
print("Responses per year: {}".format(data.groupby('Year').count()[['Combined_ID']]))
# Out:
# Total responses: 8886
# Responses per year:       Combined_ID
# Year
# 2011         6167
# 2013          193
# 2015          185
# 2017          845
# 2019         1496

# %%
yr_counts = data.groupby("Year").count()

# 2011 doesn't work because most of the questions are null
# data_2011 = data[data['Year']==2011]

data_2019 = data[data['Year']==2019]

# %%
# Note that all columns are either null or non-null
# data_2019.isna().sum()

# %%
# drop null columns
data_2019 = data_2019.dropna(axis=1)

# replace any 999.0 with null (declined to answer)
data_2019 = data_2019.replace(999.0, np.nan)
data_2019 = data_2019.replace(999, np.nan)
data_2019 = data_2019.replace('999', np.nan)

data_2019.isna().sum()

col_map = {'Combined_ID': 'id',
           'Year': 'year',
           'How.happy.do.you.feel.right.now': 'q01_happy',
           'How.satisfied.are.you.with.your.life.in.general': 'q02_satisfied_general',
           'How.satisfied.are.you.with.Somerville.as.a.place.to.live': 'q03_satisfied_somerville',
           'How.satisfied.are.you.with.your.neighborhood': 'q04_satisfied_neighborhood',
           'Do.you.feel.the.City.is.headed.in.the.right.direction.or.is.it.on.the.wrong.track': 'q05_city_direction',
           'How.would.you.rate.the.following..The.availability.of.information.about.city.services': 'q06a_city_services',
           'How.would.you.rate.the.following..The.cost.of.housing': 'q06b_cost_housing',
           'How.would.you.rate.the.following..The.overall.quality.of.public.schools': 'q06c_quality_schools',
           'How.would.you.rate.the.following..Your.trust.in.the.local.police': 'q06d_trust_police',
           'How.would.you.rate.the.following..The.maintenance.of.streets.and.sidewalks': 'q06e_sidewalks',
           'How.would.you.rate.the.following..The.availability.of.social.community.events': 'q06f_events',
           'How.safe.do.you.feel.crossing.a.busy.street.in.Somerville': 'q07_safe_crossing_street',
           'How.convenient.is.it.for.you.to.get.where.you.want.to.go': 'q08_convenient',
           'How.safe.do.you.feel.walking.in.your.neighborhood.at.night': 'q09_safe_at_night',
           'How.satisfied.are.you.with.the.appearance.of.parks.and.squares.in.your.neighborhood': 'q10_parks',
           'How.satisfied.are.you.with.the.beauty.or.physical.setting.of.your.neighborhood': 'q11_beauty',
           'How.satisfied.are.you.with.the.condition.of.your.housing': 'q12_housing_condition',
           'What.is.your.gender': 'd01_gender',
           'Age': 'd02_age',
           'Language': 'd03_language',
          'What.is.your.race.or.ethnicity': 'd04_race',
          'Do.you.have.children.age.18.or.younger.who.live.with.you': 'd05_num_children',
          'Describe.your.housing.status.in.Somerville': 'd06_housing_status',
          'Do.you.plan.to.move.away.from.Somerville.in.the.next.two.years': 'd07_plan_to_move',
          'What.is.your.annual.household.income': 'd08_hhi',
          'Are.you.a.student': 'd09_is_student',
           'How.long.have.you.lived.here': 'd10_how_long_lived_here',
          'Ward': 'ward',
          'Do.you.plan.to.move.away.from.Somerville.in.the.next.two.years.yes.why': 'move_why',
          'What.is.your.primary.mode.of.transportation': 'd11_transportation_mode',
          'Which.of.the.following.have.you.used.in.the.past.month.to.get.around': 'd12_transportation_month',
          }

# %%
# map column names 
data_2019.columns = data_2019.columns.map(col_map)

# %%
data_2019.head()
# Out:
#         id  year  q01_happy  q02_satisfied_general  q03_satisfied_somerville  \
# 7390  7391  2019       10.0                   10.0                      10.0
# 7391  7392  2019        7.0                    7.0                       9.0
# 7392  7393  2019        9.0                    9.0                       1.0
# 7393  7394  2019       10.0                    9.0                       9.0
# 7394  7395  2019        8.0                    8.0                       7.0
#
#       q04_satisfied_neighborhood  q06a_city_services  q06b_cost_housing  \
# 7390                        10.0                 5.0                4.0
# 7391                         8.0                 4.0                2.0
# 7392                         1.0                 4.0                1.0
# 7393                         8.0                 5.0                5.0
# 7394                         7.0                 5.0                3.0
#
#       q06c_quality_schools  q06d_trust_police  ...  d09_is_student  ward  \
# 7390                   4.0                5.0  ...              No   4.0
# 7391                   NaN                4.0  ...              No   6.0
# 7392                   4.0                2.0  ...              No   7.0
# 7393                   5.0                5.0  ...              No   3.0
# 7394                   4.0                5.0  ...              No   4.0
#
#       q05_city_direction  q07_safe_crossing_street  q08_convenient  \
# 7390     Right direction                       6.0             5.0
# 7391            Not sure                       9.0             8.0
# 7392         Wrong track                       2.0             1.0
# 7393     Right direction                       5.0             7.0
# 7394            Not sure                       7.0             9.0
#
#      q12_housing_condition        move_why d11_transportation_mode  \
# 7390                   9.0             NaN                     Car
# 7391                   6.0             NaN               Walk, Car
# 7392                   9.0             NaN                     Car
# 7393                   9.0  Family reasons                    Walk
# 7394                   8.0             NaN                     Car
#
#        d12_transportation_month d03_language
# 7390                        Car      English
# 7391                  Walk, Car      English
# 7392                  Walk, Car      English
# 7393  Walk, Public transit, Car      English
# 7394  Walk, Public transit, Car      Chinese
#
# [5 rows x 33 columns]

# %%
data_2019['q01_happy'].hist()
# Out:
# <AxesSubplot:>

# %%
data_2019.apply(lambda x: len(x.unique())).sort_index()
# Out:
# d01_gender                      15
# d02_age                         78
# d03_language                    81
# d04_race                        40
# d05_num_children                 3
# d06_housing_status               6
# d07_plan_to_move                 3
# d08_hhi                          9
# d09_is_student                   3
# d10_how_long_lived_here        155
# d11_transportation_mode         16
# d12_transportation_month        15
# id                            1496
# move_why                       378
# q01_happy                       11
# q02_satisfied_general           11
# q03_satisfied_somerville        11
# q04_satisfied_neighborhood      11
# q05_city_direction               4
# q06a_city_services               6
# q06b_cost_housing                6
# q06c_quality_schools             6
# q06d_trust_police                6
# q06e_sidewalks                   6
# q06f_events                      6
# q07_safe_crossing_street        11
# q08_convenient                  11
# q09_safe_at_night               11
# q10_parks                       11
# q11_beauty                      11
# q12_housing_condition           11
# ward                             9
# year                             1
# dtype: int64

# %%
data_2019.groupby('d02_age').count()[['id']]
# Out:
#          id
# d02_age
# 17        1
# 19        1
# 20        1
# 21        5
# 22        3
# ...      ..
# 91        2
# 94        1
# 95        1
# 96        1
# 98        1
#
# [77 rows x 1 columns]

# %%
def map_gender(v):
    if v not in ('Female', 'Male', 'No Answer'):
        return 'Non-binary'
    else:
        return v
    
def map_age(v):
    if v <= 24:
        return '17_24'
    elif v <= 34:
        return '25_34'
    elif v <= 44:
        return '35_44'
    elif v <= 54:
        return '45_54'
    else:
        return '55+'

data_2019['d01_gender'] = data_2019['d01_gender'].fillna('No Answer')    
data_2019['d01_gender'] = data_2019['d01_gender'].apply(lambda x: map_gender(x))
# data_2019.groupby('d01_gender').count()

data_2019['d02_age'] = pd.to_numeric(data_2019['d02_age'])
data_2019['d02_age'] = data_2019['d02_age'].apply(lambda x: map_age(x))
data_2019['d02_age'] = data_2019['d02_age'].fillna('No Answer')

# %%
data_2019['d11_car'] = data_2019['d11_transportation_mode'].str.contains('Car') * 1
data_2019['d11_walk'] = data_2019['d11_transportation_mode'].str.contains('Walk') * 1
data_2019['d11_bike'] = data_2019['d11_transportation_mode'].str.contains('Bike') * 1
data_2019['d11_public'] = data_2019['d11_transportation_mode'].str.contains('Public') * 1

data_2019.drop('d11_transportation_mode', axis=1, inplace=True)

data_2019['d12_car'] = data_2019['d12_transportation_month'].str.contains('Car') * 1
data_2019['d12_walk'] = data_2019['d12_transportation_month'].str.contains('Walk') * 1
data_2019['d12_bike'] = data_2019['d12_transportation_month'].str.contains('Bike') * 1
data_2019['d12_public'] = data_2019['d12_transportation_month'].str.contains('Public') * 1

data_2019.drop('d12_transportation_month', axis=1, inplace=True)

# %%
city_direction_map = {'Right direction': 'right',
                     'Wrong track': 'wrong',
                     'Not sure': 'unsure',}

data_2019['q05_city_direction'] = data_2019['q05_city_direction'].map(city_direction_map)
data_2019['q05_city_direction'].fillna('no_answer', inplace=True)

# %%
data_2019['d03_language'] = data_2019['d03_language'].str.lower()

data_2019['d03_english'] = data_2019['d03_language'].str.contains('english') * 1
data_2019['d03_spanish'] = data_2019['d03_language'].str.contains('spanish') * 1
data_2019['d03_portuguese'] = data_2019['d03_language'].str.contains('portuguese') * 1

searchfor = ['mandarin', 'chinese', 'contonese']
data_2019['d03_chinese'] = data_2019['d03_language'].str.contains('|'.join(searchfor)) * 1

searchfor = ['arabic', 'greek', 'french', 'punjabi', 'amharic', 
             'gujrati', 'nepali', 'tigrinya', 'polish', 'filipino',
             'italian', 'japanese', 'russian', 'haitian creole', 'kreole', 'romanian',
             'slovac', 'vietnnamese', 'esperanto', 'hebrew', 'bulgarian', 'latin',
            'persian', 'romanian']
data_2019['d03_other'] = data_2019['d03_language'].str.contains('|'.join(searchfor)) * 1

data_2019.drop('d03_language', axis=1, inplace=True)

# %%
searchfor = ['hispanic', 'puerto rican']
data_2019['d04_eth_hispanic'] = pd.to_numeric(data_2019['d04_race'].str.contains('|'.join(searchfor)) * 1)

data_2019['d04_eth_brazilian'] = pd.to_numeric(data_2019['d04_race'].str.contains('brazilian') * 1)
data_2019['d04_race_white'] = pd.to_numeric(data_2019['d04_race'].str.contains('white') * 1)
data_2019['d04_race_aa'] = pd.to_numeric(data_2019['d04_race'].str.contains('black') * 1)
data_2019['d04_race_asian'] = pd.to_numeric(data_2019['d04_race'].str.contains('asian') * 1)

searchfor = ['jewish', 'american indian', 'portuguese', 'cape verdean', 
             'middle eastern', 'east indian', 'biracial', 'arab', 'brazilian']
data_2019['d04_race_other'] = pd.to_numeric(data_2019['d04_race'].str.contains('|'.join(searchfor)) * 1)

data_2019.drop('d04_race', axis=1, inplace=True)

# %%
pd.to_numeric(data_2019['d04_eth_brazilian'])
# Out:
# 7390    0.0
# 7391    0.0
# 7392    0.0
# 7393    0.0
# 7394    0.0
#        ...
# 8881    0.0
# 8882    0.0
# 8883    0.0
# 8884    0.0
# 8885    0.0
# Name: d04_eth_brazilian, Length: 1496, dtype: float64

# %%
hhi_map = {'Less than $10,000': 1,
           '$10,000 to $24,999': 2,
           '$25,000 to $49,999': 3,
           '$50,000 to 74,999': 4,
           '$75,000 to $99,999': 5,
           '$100,000 to $149,999': 6,
           '$150,000 to 200,000': 7,
           '$200,000 or more': 8}

data_2019['d08_hhi'] = data_2019['d08_hhi'].map(hhi_map)

# %%
data_2019['d10_how_long_lived_here'] = data_2019['d10_how_long_lived_here'].str.replace("999", '-')

# %%
data_2019['d10_how_long_lived_here'] = data_2019['d10_how_long_lived_here'].str.lower()
data_2019['d10_how_long_lived_here'] = data_2019['d10_how_long_lived_here'].str.replace("999", '-')
data_2019['d10_how_long_lived_here'].fillna("no_answer", inplace=True)
data_2019['d10_how_long_lived_here'] = data_2019['d10_how_long_lived_here'].apply(lambda x: x[7:] if x.startswith("almost ") else x)
data_2019['d10_how_long_lived_here'] = data_2019['d10_how_long_lived_here'].apply(lambda x: x[7:] if x.startswith("about ") else x)
data_2019['d10_how_long_lived_here'] = data_2019['d10_how_long_lived_here'].apply(lambda x: x[7:] if x.startswith("over ") else x)

# %%
def format_years(v):
    

    # just a number, assume it's years
    p = '^([\.\d]+)$'
    r = re.findall(p, v)
    
    if len(r) > 0:
        return int(float(r[0]))
    
    # "3.5 years"
    p = '^([\.\d]+) years$'
    r = re.findall(p, v)
    
    if len(r) > 0:
        return int(float(r[0]))

    # "30+ years"
    p = '^([\.\d]+)\+ years$'
    r = re.findall(p, v)
    
    if len(r) > 0:
        return int(float(r[0]))
    
    # "9 months"
    p = '^([\.\d]+) months$'
    r = re.findall(p, v)
    
    if len(r) > 0:
        return int(float(r[0]) / 12)
    
    # "3 weeks"
    p = '^([\.\d]+) weeks$'
    r = re.findall(p, v)
    
    if len(r) > 0:
        return 0
    
    # "6-8 years"
    p = '^([\.\d]+)-([\.\d]+) years$'
    r = re.findall(p, v)
    
    if len(r) > 0:
        return int(float(r[0][1]))
    
    # "1 year, 9 months"
    p = '^([\.\d]+) year, ([\.\d]+) months$'
    r = re.findall(p, v)
    
    if len(r) > 0:
        return int(float(r[0][0]))
    
    # "3 days"
    p = '^([\.\d]+) days$'
    r = re.findall(p, v)
    
    if len(r) > 0:
        return 0
    
    if v == '1 year':
        return 1
    
    if v == '1 month':
        return 0
    
    years_map = {'no_answer': np.nan,
             '1 month, two years before from 2010-2012': 2,
             '4  months': 0,
             '5 years + 10 years before': 15,
             '`17 years': 17,
             'less than 1 year': 0,
             '11years': 11,
             '3 generations': np.nan,
             '1 year thist ime; 6 years total': 6,
             '1 year 2 months': 1,
             'too long': np.nan,
             '50 +': 50,
             ' years': np.nan,
             '16+': 16,
             '14 years; 11 years now': 14,
             '1 year 3 months': 1,
             'less than 10 months': 0,
             '30+': 30,
             '8.5 yesrs': 8.5,
             'life long resident': 50,
             '1 year this time; 6 years total': 6
            }
    
    if v in years_map.keys():
        return years_map[v]
    
    else:
        print(v)

# %%
data_2019['d10_how_long_lived_here'] = data_2019['d10_how_long_lived_here'].apply(lambda x: format_years(x))
data_2019['d10_bins'] = pd.qcut(data_2019['d10_how_long_lived_here'], q=4)
data_2019.drop('d10_how_long_lived_here', axis=1, inplace=True)

# %%
data_2019['d06_housing_status'].unique()

def format_housing_status(v):
    if v == 'Rent':
        return v
    
    elif v == 'Own':
        return v
    
    else:
        return 'Other'

# %%
data_2019['d06_housing_status'] = data_2019['d06_housing_status'].apply(lambda x: format_housing_status(x))

# %%
data_2019.apply(lambda x: len(x.unique())).sort_index()
# Out:
# d01_gender                       4
# d02_age                          5
# d03_chinese                      3
# d03_english                      3
# d03_other                        3
# d03_portuguese                   3
# d03_spanish                      3
# d04_eth_brazilian                2
# d04_eth_hispanic                 2
# d04_race_aa                      2
# d04_race_asian                   2
# d04_race_other                   2
# d04_race_white                   3
# d05_num_children                 3
# d06_housing_status               3
# d07_plan_to_move                 3
# d08_hhi                          9
# d09_is_student                   3
# d10_bins                         5
# d11_bike                         3
# d11_car                          3
# d11_public                       3
# d11_walk                         3
# d12_bike                         3
# d12_car                          3
# d12_public                       3
# d12_walk                         3
# id                            1496
# move_why                       378
# q01_happy                       11
# q02_satisfied_general           11
# q03_satisfied_somerville        11
# q04_satisfied_neighborhood      11
# q05_city_direction               4
# q06a_city_services               6
# q06b_cost_housing                6
# q06c_quality_schools             6
# q06d_trust_police                6
# q06e_sidewalks                   6
# q06f_events                      6
# q07_safe_crossing_street        11
# q08_convenient                  11
# q09_safe_at_night               11
# q10_parks                       11
# q11_beauty                      11
# q12_housing_condition           11
# ward                             9
# year                             1
# dtype: int64

# %%
data_2019.groupby('d08_hhi').count()
# Out:
#           id  year  q01_happy  q02_satisfied_general  \
# d08_hhi
# 1.0       46    46         43                     43
# 2.0       90    90         86                     84
# 3.0      142   142        141                    140
# 4.0      218   218        212                    213
# 5.0      184   184        184                    184
# 6.0      276   276        272                    272
# 7.0      180   180        178                    178
# 8.0      224   224        224                    224
#
#          q03_satisfied_somerville  q04_satisfied_neighborhood  \
# d08_hhi
# 1.0                            45                          44
# 2.0                            86                          86
# 3.0                           141                         141
# 4.0                           214                         215
# 5.0                           182                         183
# 6.0                           275                         275
# 7.0                           180                         179
# 8.0                           223                         223
#
#          q06a_city_services  q06b_cost_housing  q06c_quality_schools  \
# d08_hhi
# 1.0                      46                 45                    42
# 2.0                      86                 87                    69
# 3.0                     136                139                   111
# 4.0                     217                217                   167
# 5.0                     183                184                   149
# 6.0                     273                275                   207
# 7.0                     179                180                   142
# 8.0                     224                222                   175
#
#          q06d_trust_police  ...  d03_portuguese  d03_chinese  d03_other  \
# d08_hhi                     ...
# 1.0                     44  ...              42           42         42
# 2.0                     85  ...              85           85         85
# 3.0                    139  ...             134          134        134
# 4.0                    208  ...             208          208        208
# 5.0                    175  ...             176          176        176
# 6.0                    268  ...             265          265        265
# 7.0                    177  ...             173          173        173
# 8.0                    221  ...             221          221        221
#
#          d04_eth_hispanic  d04_eth_brazilian  d04_race_white  d04_race_aa  \
# d08_hhi
# 1.0                    43                 43              43           43
# 2.0                    86                 86              86           86
# 3.0                   141                141             141          141
# 4.0                   208                208             208          208
# 5.0                   178                178             178          178
# 6.0                   270                270             270          270
# 7.0                   171                171             171          171
# 8.0                   218                218             218          218
#
#          d04_race_asian  d04_race_other  d10_bins
# d08_hhi
# 1.0                  43              43        40
# 2.0                  86              86        85
# 3.0                 141             141       132
# 4.0                 208             208       206
# 5.0                 178             178       174
# 6.0                 270             270       263
# 7.0                 171             171       168
# 8.0                 218             218       214
#
# [8 rows x 47 columns]

# %%
data_2019.dtypes
# Out:
# id                               int64
# year                             int64
# q01_happy                      float64
# q02_satisfied_general          float64
# q03_satisfied_somerville       float64
# q04_satisfied_neighborhood     float64
# q06a_city_services             float64
# q06b_cost_housing              float64
# q06c_quality_schools           float64
# q06d_trust_police              float64
# q06e_sidewalks                 float64
# q06f_events                    float64
# q09_safe_at_night              float64
# q11_beauty                     float64
# q10_parks                      float64
# d01_gender                      object
# d02_age                         object
# d05_num_children                object
# d06_housing_status              object
# d07_plan_to_move                object
# d08_hhi                        float64
# d09_is_student                  object
# ward                           float64
# q05_city_direction              object
# q07_safe_crossing_street       float64
# q08_convenient                 float64
# q12_housing_condition          float64
# move_why                        object
# d11_car                         object
# d11_walk                        object
# d11_bike                        object
# d11_public                      object
# d12_car                         object
# d12_walk                        object
# d12_bike                        object
# d12_public                      object
# d03_english                     object
# d03_spanish                     object
# d03_portuguese                  object
# d03_chinese                     object
# d03_other                       object
# d04_eth_hispanic                object
# d04_eth_brazilian               object
# d04_race_white                  object
# d04_race_aa                     object
# d04_race_asian                  object
# d04_race_other                  object
# d10_bins                      category
# dtype: object
